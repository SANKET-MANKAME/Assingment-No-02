# %% [markdown]
# 1)Generate random data with numpy that contain 1000 data points with two coloumns allow.

# %%
import numpy as np
import pandas as pd

# %%
 arr = np.array([[i for i in range(0,1000)]]) 
print(arr.shape)
arr=arr.reshape(500,2)
Col=['Column1','Column2']
Table=pd.DataFrame(data=arr, columns=Col)
print(Table)

# %% [markdown]
# 2) Scatter plot and line plot with all variations

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#inialization of values for x, y, z data points using normal list
 
x= [10,20,30,40,50,60]
y=[9, 18,27,36,45,54]
z=[8 , 16, 24, 32,40,48]
 
#Creating a subplot 1
plt.subplot(2,2,1) 
 
#1st line graph
plt.plot(x,y,c='r', marker='^', mec='k',linewidth=2,label="xy plane")
plt.xlabel("x-axis") 
plt.ylabel("y-axis") 
plt.title("Assignment LineGraph1") 
plt.legend()
 
 
#Creating a subplot 2
plt.subplot(2,2,2) 
 
#2 lineplot in one graph
plt.plot(x,y,c='r', marker='^', mec='k',linewidth=2,label="xy plane")
plt.plot(x, z, c='g', marker='*', mec='y', linewidth=4, label='xz plane')
plt.xlabel("x-axis") 
plt.ylabel("y-axis") 
plt.title("Assignment LineGraph2") 
plt.legend()
 
 
 
#Intialization of a, b, c using numpy library
a=np.arange(0, 10) 
b=np.random.rand(10)
c=[i for i in range(10)]
 
#creating subolot3
plt.subplot(2,2,3)
 
#Creating 1st scatter plot
plt.scatter(a, b,c='red', marker='+', label="ab plane") 
plt.xlabel("x-axis") 
plt.ylabel("y-axis") 
plt.title("Assignment scatter plot1") 
plt.legend()
 
#Creating Subplot 4
plt. subplot(2,2,4) 
 
#Creating 2 scatter plot in one graph
plt.scatter(a, b,c='hotpink',marker='s', label="ab plane")
plt.scatter(a,c,c='blue', marker='d',label="ac plane") 
plt.xlabel("x-axis") 
plt.ylabel("y-axis") 
plt.title("Assignment scatter plot2") 
plt.legend()
 
#Adjusting the spaces between subplots
plt.subplots_adjust(left=2, right=4, top=4, bottom=2)
 
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# 3)DATA ANALYSIS ON BOSTON DATA SET AND INSIGHTS

# %%
 '''
Boston dataset contains data about the house prices in Boston. 
Prices of houses are depended on the different attributes like
CRIM: Per capita crime rate by town
ZN: Proportion of residential land zoned for lots over 25,000 sq. ft
INDUS: Proportion of non-retail business acres per town
CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
NOX: Nitric oxide concentr ation (parts per 10 million)
RM: Average number of rooms per dwelling
AGE: Proportion of owner-occupied units built prior to 1940
DIS: Weighted distances to five Boston employment centers
RAD: Index of accessibility to radial highways
TAX: Full-value property tax rate per $10,000
PTRATIO: Pupil-teacher ratio by town
B: 1000(Bk — 0.63)², where Bk is the proportion of [people of African American descent] by town
LSTAT: Percentage of lower status of the population
MEDV: Median value of owner-occupied homes in $1000s
 
MEDV IS THE TARGET DATA
 
Now we will do data analysis on two attributes that are CRIM and LSTAT
'''

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn.datasets import load_boston
boston_dataset=load_boston()
boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
boston['MEDV'] = boston_dataset.target
 
X=boston['CRIM']
Y=boston['LSTAT']
Z=boston['MEDV']

# %%
 
plt.subplot(2,2,1)
plt.hist(X, bins=30,label='CRIM')
plt.xlabel('Crime rate')
plt.ylabel('Per town')
plt.legend() 
plt.subplot(2,2,2)
plt.hist(Y, bins=30,color='r',label='LSTAT')
plt.xlabel('percentage of lower status of the population') 
plt.ylabel('town')
plt.legend()
plt.subplot(2,2,3)
plt.hist(Z, bins=30,color='k',label='MEDV')
plt.xlabel('Median value of owner-occupied homes')
plt.ylabel('10,000$') 
plt.legend()
plt.subplots_adjust(left=2, right=4, top=4, bottom=2) 
plt.show()

# %% [markdown]
# From above graph we can see that the pricing of the house in Boston are inversely proportional to CRIM and LSTAT. So when CRIM and LSTAT increase the pricing increases.

# %% [markdown]
# 4) Simple linear regression applied on breast cancer dataset.

# %%
# !pip install sklearn

# %%
import sklearn as sk
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data=load_breast_cancer() 
label=data['target']
features=data['data']
X_train, X_test, Y_train, Y_test=train_test_split(features, label,test_size=0.2,random_state=1)
lr= LinearRegression()
model= lr.fit(X_train, Y_train)
Score=lr.score(X_train, Y_train) 
print('Score is :-',Score)
# Out:
# Score is :- 0.7803836061574759
